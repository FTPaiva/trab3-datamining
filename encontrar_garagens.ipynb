# %%
import psycopg2
import pandas as pd
import folium
from geopy.distance import great_circle
from sklearn.cluster import DBSCAN
import numpy as np
from datetime import datetime
from collections import Counter
from sqlalchemy import create_engine

# %%
USED_BUS_LINES = ['100', '108', '232', '2336', '2803', '292', '298', '3', '309', '315', '324', '328', '343', '355', '371', '388', 
                  '397', '399', '415', '422', '457', '483', '497', '550', '553', '554', '557', '565', '606', '624', '629', '634', 
                  '638', '639', '665', '756', '759', '774', '779', '803', '838', '852', '864', '867', '878', '905', '917', '918']

# %%
database_uri = 'postgresql://postgres:senha@localhost:5432/postgres'
db_engine_alchemy = create_engine(database_uri)

# %%
def database_query_alchemy(linha, engine) -> pd.DataFrame:
    query = (   f'SELECT ordem, latitude, longitude, datahora_ts, velocidade ' 
                f'FROM gps '
                f'WHERE linha = \'{linha}\' '
                f'AND EXTRACT (HOUR FROM datahora_ts) in (23, 0, 1, 2, 3)'
                f'AND velocidade = 0 '
                f'AND EXTRACT (MONTH FROM datahora_ts) = 5'
    )
    df = pd.read_sql(query, con=engine)
    return df

# %%
def get_clusters(linha: str, engine, radius_meters: int = 30) -> pd.DataFrame:
    query = f"""
    WITH pontos_filtrados AS (
        SELECT ordem, latitude, longitude, datahora_ts
        FROM gps
        WHERE linha = '{linha}'
          AND velocidade = 0
          AND EXTRACT(HOUR FROM datahora_ts) IN (23, 0, 1, 2, 3)
          AND EXTRACT(MONTH FROM datahora_ts) = 5
    ),
    pontos_geometrizados AS (
        SELECT *,
               ST_Transform(ST_SetSRID(ST_MakePoint(longitude, latitude), 4326), 3857) AS geom
        FROM pontos_filtrados
    ),
    clusters AS (
        SELECT *,
               ST_ClusterDBSCAN(geom, {radius_meters}, 1) OVER () AS cluster
        FROM pontos_geometrizados
    ),
    agregados AS (
        SELECT cluster,
               COUNT(*) AS pontos,
               AVG(latitude) AS center_lat,
               AVG(longitude) AS center_lon
        FROM clusters
        WHERE cluster IS NOT NULL
        GROUP BY cluster
        ORDER BY pontos DESC
        LIMIT 5
    )
    SELECT cluster, center_lat, center_lon, pontos
    FROM agregados;
    """
    return pd.read_sql(query, con=engine)

# %%
def process_cluster_result(df_clusters: pd.DataFrame):
    centroids_result = []
    print("Top selected areas:")
    for i, row in enumerate(df_clusters.itertuples(index=False), start=1):
        print(f"Cluster {row.cluster}: Center ({row.center_lat}, {row.center_lon}), Count: {row.pontos}")
        centroids_result.append((i, (row.center_lat, row.center_lon), row.pontos))
    return centroids_result

# %%
bus_stops_per_line = {}

# %%
STOP_RADIUS = 30  # em metros

for linha in USED_BUS_LINES:
    if linha == '3':
        continue
    df_clusters = get_clusters(linha, db_engine_alchemy, radius_meters=STOP_RADIUS)
    print(f"[{linha}] Tamanho df filtrado: {df_clusters['pontos'].sum()}")
    bus_stops_per_line[linha] = process_cluster_result(df_clusters)
# Out:
# [100] Tamanho df filtrado: 29953
# Top selected areas:
# Cluster 0: Center (-22.889049803705454, -43.29265409016953), Count: 19053
# Cluster 1: Center (-22.874949986885245, -43.24128354098361), Count: 7625
# Cluster 61: Center (-22.946192821479038, -43.181662623645785), Count: 2123
# Cluster 6: Center (-22.904698373056995, -43.192202279792745), Count: 965
# Cluster 118: Center (-22.84272, -43.25382), Count: 187
# [108] Tamanho df filtrado: 14074
# Top selected areas:
# Cluster 0: Center (-22.874891398704357, -43.241308679328625), Count: 13584
# Cluster 1: Center (-22.899212553699282, -43.21181105011933), Count: 419
# Cluster 79: Center (-22.91330357142857, -43.18050142857143), Count: 28
# Cluster 33: Center (-22.93003681818182, -43.186451363636365), Count: 22
# Cluster 38: Center (-22.88606619047619, -43.224967142857146), Count: 21
# [232] Tamanho df filtrado: 10577
# Top selected areas:
# Cluster 2: Center (-22.902309183590987, -43.29846899464484), Count: 9897
# Cluster 21: Center (-22.90072454258675, -43.29027876971609), Count: 317
# Cluster 11: Center (-22.908860909090908, -43.17023533596838), Count: 253
# Cluster 6: Center (-22.905110526315788, -43.2887347368421), Count: 76
# Cluster 22: Center (-22.905091176470588, -43.29295470588235), Count: 34
# [2336] Tamanho df filtrado: 34673
# Top selected areas:
# Cluster 0: Center (-22.917126022414052, -43.60795801272149), Count: 33015
# Cluster 1: Center (-22.901758827054795, -43.55853977739726), Count: 1168
# Cluster 14: Center (-22.86033606557377, -43.455711377049184), Count: 305
# Cluster 22: Center (-22.90248443708609, -43.56217483443709), Count: 151
# Cluster 19: Center (-22.89046882352941, -43.55957176470588), Count: 34
# [2803] Tamanho df filtrado: 17295
# Top selected areas:
# Cluster 0: Center (-22.89412085998793, -43.53226972420036), Count: 16570
# Cluster 6: Center (-22.85621990430622, -43.493153684210526), Count: 209
# Cluster 63: Center (-22.85641064516129, -43.49393650537635), Count: 186
# Cluster 7: Center (-22.890387556818183, -43.52550534090909), Count: 176
# Cluster 24: Center (-23.007662792207793, -43.30391577922078), Count: 154
# [292] Tamanho df filtrado: 17184
# Top selected areas:
# Cluster 3: Center (-22.868335049668875, -43.291568515954246), Count: 6644
# Cluster 4: Center (-22.817308034926118, -43.39347324313951), Count: 5211
# Cluster 0: Center (-22.817180386740333, -43.30156703098727), Count: 4163
# Cluster 2: Center (-22.865397973137974, -43.29952451770452), Count: 819
# Cluster 8: Center (-22.81515129682997, -43.38211253602306), Count: 347
# [298] Tamanho df filtrado: 13187
# Top selected areas:
# Cluster 0: Center (-22.817525646753246, -43.39341847532467), Count: 11550
# Cluster 1: Center (-22.830930524475523, -43.3533687995338), Count: 858
# Cluster 32: Center (-22.909134281524928, -43.17093428152493), Count: 341
# Cluster 102: Center (-22.814366706349205, -43.38249242063492), Count: 252
# Cluster 116: Center (-22.815109086021504, -43.38210865591398), Count: 186
# [309] Tamanho df filtrado: 48096
# Top selected areas:
# Cluster 0: Center (-22.87488907706609, -43.24136370899916), Count: 45182
# Cluster 11: Center (-22.904797445141067, -43.192486959247645), Count: 2552
# Cluster 38: Center (-23.00151172248804, -43.36525913875598), Count: 209
# Cluster 23: Center (-22.992644642857144, -43.24865761904762), Count: 84
# Cluster 42: Center (-22.993420289855074, -43.25383695652174), Count: 69
# [315] Tamanho df filtrado: 28673
# Top selected areas:
# Cluster 0: Center (-22.874921169055202, -43.24127755661713), Count: 22608
# Cluster 1: Center (-22.904877039274925, -43.192525334484245), Count: 2317
# Cluster 18: Center (-22.952333391148326, -43.34884783492823), Count: 1672
# Cluster 61: Center (-22.860752955784374, -43.35579311326469), Count: 1651
# Cluster 15: Center (-23.020901082352943, -43.48270943529412), Count: 425
# [324] Tamanho df filtrado: 18574
# Top selected areas:
# Cluster 0: Center (-22.815526611613052, -43.188287314265985), Count: 17377
# Cluster 1: Center (-22.825560118110236, -43.16932763779528), Count: 1016
# Cluster 33: Center (-22.900595280898877, -43.17811235955056), Count: 89
# Cluster 4: Center (-22.81908107142857, -43.18338178571429), Count: 56
# Cluster 37: Center (-22.90135972222222, -43.17975222222222), Count: 36
# [328] Tamanho df filtrado: 41899
# Top selected areas:
# Cluster 1: Center (-22.81507887453534, -43.18740191452901), Count: 37931
# Cluster 0: Center (-22.789024239583334, -43.161897215277776), Count: 2880
# Cluster 27: Center (-22.902532113970587, -43.18211985294118), Count: 544
# Cluster 84: Center (-22.90115581218274, -43.177815482233505), Count: 394
# Cluster 5: Center (-22.9050592, -43.191653333333335), Count: 150
# [343] Tamanho df filtrado: 9512
# Top selected areas:
# Cluster 3: Center (-22.95093626288275, -43.34825974010455), Count: 6695
# Cluster 4: Center (-23.00552371402467, -43.31253851073549), Count: 2189
# Cluster 15: Center (-22.987659843400447, -43.30934096196868), Count: 447
# Cluster 78: Center (-22.902213775510205, -43.18174030612245), Count: 98
# Cluster 39: Center (-22.875135301204818, -43.24259277108434), Count: 83
# [355] Tamanho df filtrado: 21031
# Top selected areas:
# Cluster 0: Center (-22.860825786254352, -43.35584583212981), Count: 11771
# Cluster 1: Center (-22.81711374445149, -43.30173022828155), Count: 6308
# Cluster 18: Center (-22.871283186567165, -43.34112314925373), Count: 1340
# Cluster 112: Center (-22.87006533640553, -43.341527769585255), Count: 1085
# Cluster 2: Center (-22.90731074003795, -43.18280356736243), Count: 527
# [371] Tamanho df filtrado: 3253
# Top selected areas:
# Cluster 4: Center (-22.877073896529144, -43.368081899148656), Count: 1527
# Cluster 3: Center (-22.901397463002112, -43.347278583509514), Count: 946
# Cluster 5: Center (-22.89877365116279, -43.35236106976744), Count: 430
# Cluster 12: Center (-22.89779403587444, -43.352290672645736), Count: 223
# Cluster 10: Center (-22.900367716535435, -43.354142125984254), Count: 127
# [388] Tamanho df filtrado: 6507
# Top selected areas:
# Cluster 4: Center (-22.935632067661274, -43.65591509140576), Count: 4759
# Cluster 3: Center (-22.90147483724451, -43.18048240726722), Count: 1321
# Cluster 20: Center (-22.855195286624205, -43.492234968152864), Count: 157
# Cluster 23: Center (-22.905566666666665, -43.193217872340426), Count: 141
# Cluster 291: Center (-22.880077131782947, -43.62595217054263), Count: 129
# [397] Tamanho df filtrado: 8611
# Top selected areas:
# Cluster 0: Center (-22.902084546132063, -43.554754596810255), Count: 6709
# Cluster 6: Center (-22.901383623623623, -43.180162802802805), Count: 999
# Cluster 5: Center (-22.883551142857144, -43.49504661654135), Count: 665
# Cluster 13: Center (-22.905570296296297, -43.19325311111111), Count: 135
# Cluster 75: Center (-22.873130679611652, -43.46491067961165), Count: 103
# [399] Tamanho df filtrado: 14951
# Top selected areas:
# Cluster 1: Center (-22.817409505139256, -43.393484735576926), Count: 12064
# Cluster 6: Center (-22.814617818608287, -43.38239473807662), Count: 1279
# Cluster 16: Center (-22.806735471365638, -43.36647117180617), Count: 1135
# Cluster 18: Center (-22.915786666666666, -43.17648064285714), Count: 420
# Cluster 44: Center (-22.905197924528302, -43.1920879245283), Count: 53
# [415] Tamanho df filtrado: 13363
# Top selected areas:
# Cluster 0: Center (-22.93006589981926, -43.25422707203718), Count: 11619
# Cluster 37: Center (-22.946320399257196, -43.256618848653666), Count: 1077
# Cluster 29: Center (-22.905735560165976, -43.192714522821575), Count: 241
# Cluster 26: Center (-22.932441722689077, -43.24091773109244), Count: 238
# Cluster 18: Center (-22.924134680851065, -43.232701382978725), Count: 188
# [422] Tamanho df filtrado: 39162
# Top selected areas:
# Cluster 0: Center (-22.88949726019001, -43.292331199560735), Count: 39156
# Cluster 9: Center (-22.891315, -43.29142), Count: 2
# Cluster 11: Center (-22.911425, -43.272435), Count: 2
# Cluster 2: Center (-22.90334, -43.26957), Count: 1
# Cluster 4: Center (-22.88751, -43.28738), Count: 1
# [457] Tamanho df filtrado: 20398
# Top selected areas:
# Cluster 0: Center (-22.889417934756537, -43.29245393139842), Count: 12507
# Cluster 14: Center (-22.868308688245314, -43.29155058603067), Count: 2935
# Cluster 23: Center (-22.817342827490776, -43.393539446494465), Count: 2168
# Cluster 27: Center (-22.885810361388494, -43.30038868283405), Count: 2103
# Cluster 4: Center (-22.902947270072993, -43.31397496350365), Count: 685
# [483] Tamanho df filtrado: 67742
# Top selected areas:
# Cluster 2: Center (-22.804420101406926, -43.3099655551255), Count: 51673
# Cluster 1: Center (-22.836854964028777, -43.28412425391451), Count: 11815
# Cluster 0: Center (-22.98579119072708, -43.196992307692305), Count: 1898
# Cluster 86: Center (-22.946983241491086, -43.181834878444086), Count: 1234
# Cluster 60: Center (-22.83728303030303, -43.28694071301248), Count: 1122
# [497] Tamanho df filtrado: 43490
# Top selected areas:
# Cluster 0: Center (-22.804488174963474, -43.310037351283654), Count: 38328
# Cluster 4: Center (-22.83683632631579, -43.28392757894737), Count: 3800
# Cluster 173: Center (-22.629406645702307, -43.17644649895178), Count: 477
# Cluster 10: Center (-22.931512617021276, -43.177580978723405), Count: 470
# Cluster 64: Center (-22.837225180722893, -43.28709739759036), Count: 415
# [550] Tamanho df filtrado: 26147
# Top selected areas:
# Cluster 1: Center (-22.950924606442452, -43.348161994409445), Count: 22538
# Cluster 7: Center (-22.979065301444944, -43.22273316392626), Count: 2007
# Cluster 8: Center (-22.946439233305853, -43.36021662819456), Count: 1213
# Cluster 18: Center (-22.993444549763034, -43.25375957345972), Count: 211
# Cluster 2: Center (-22.972340449438203, -43.33092960674157), Count: 178
# [553] Tamanho df filtrado: 12226
# Top selected areas:
# Cluster 2: Center (-22.95229251588609, -43.348931063779716), Count: 8498
# Cluster 0: Center (-23.02079433497537, -43.48280354679803), Count: 2639
# Cluster 36: Center (-22.954277056530213, -43.178712436647174), Count: 513
# Cluster 136: Center (-23.019633980582523, -43.48213139158576), Count: 309
# Cluster 91: Center (-22.874453707865168, -43.24172007490637), Count: 267
# [554] Tamanho df filtrado: 21018
# Top selected areas:
# Cluster 3: Center (-22.952276672139337, -43.34893686058962), Count: 14009
# Cluster 0: Center (-23.02499668720191, -43.52160006955485), Count: 5032
# Cluster 22: Center (-22.954302736248238, -43.17875234132581), Count: 1418
# Cluster 186: Center (-23.011822335526315, -43.51381427631579), Count: 304
# Cluster 338: Center (-22.98536737254902, -43.19023290196078), Count: 255
# [557] Tamanho df filtrado: 13880
# Top selected areas:
# Cluster 3: Center (-22.95123668846555, -43.34820035446877), Count: 10551
# Cluster 12: Center (-22.968422058175406, -43.33610934332305), Count: 2269
# Cluster 28: Center (-22.985498385744236, -43.19018174004193), Count: 477
# Cluster 2: Center (-22.96672493796526, -43.18672446650124), Count: 403
# Cluster 27: Center (-22.987349166666668, -43.308573555555554), Count: 180
# [565] Tamanho df filtrado: 18321
# Top selected areas:
# Cluster 0: Center (-22.95105489737963, -43.348248618820186), Count: 15494
# Cluster 1: Center (-22.91585647353362, -43.36126717453505), Count: 1398
# Cluster 28: Center (-22.978964189944133, -43.222242737430165), Count: 895
# Cluster 77: Center (-22.88016730458221, -43.35770320754717), Count: 371
# Cluster 18: Center (-22.993492883435582, -43.25392809815951), Count: 163
# [606] Tamanho df filtrado: 19755
# Top selected areas:
# Cluster 0: Center (-22.902283469332023, -43.2984125785133), Count: 18309
# Cluster 14: Center (-22.89576461448598, -43.294192628504675), Count: 856
# Cluster 8: Center (-22.89950177130045, -43.21093679372197), Count: 446
# Cluster 1: Center (-22.924346571428572, -43.23303761904762), Count: 105
# Cluster 46: Center (-22.90190846153846, -43.27976692307692), Count: 39
# [624] Tamanho df filtrado: 1780
# Top selected areas:
# Cluster 4: Center (-22.87707435921422, -43.36734010289991), Count: 1069
# Cluster 29: Center (-22.829073477011494, -43.41909261494253), Count: 348
# Cluster 40: Center (-22.911637044025156, -43.21195849056604), Count: 159
# Cluster 2: Center (-22.86128889908257, -43.37135880733945), Count: 109
# Cluster 10: Center (-22.877166736842106, -43.36392021052632), Count: 95
# [629] Tamanho df filtrado: 21224
# Top selected areas:
# Cluster 0: Center (-22.817122551056134, -43.30157616174583), Count: 17138
# Cluster 18: Center (-22.825202196659312, -43.33246939174283), Count: 3173
# Cluster 25: Center (-22.922878657024793, -43.23252776859504), Count: 484
# Cluster 13: Center (-22.82851262589928, -43.3194126618705), Count: 278
# Cluster 34: Center (-22.885908410596027, -43.251910927152316), Count: 151
# [634] Tamanho df filtrado: 26879
# Top selected areas:
# Cluster 0: Center (-22.815045419731977, -43.18737116156997), Count: 25147
# Cluster 6: Center (-22.78906111883252, -43.16186676164003), Count: 1439
# Cluster 9: Center (-22.926807370892018, -43.23400469483568), Count: 213
# Cluster 1: Center (-22.839491296296295, -43.23955740740741), Count: 54
# Cluster 75: Center (-22.924523461538463, -43.233784615384614), Count: 26
# [638] Tamanho df filtrado: 29156
# Top selected areas:
# Cluster 0: Center (-22.860757349873133, -43.355837512686776), Count: 28376
# Cluster 39: Center (-22.92528391509434, -43.232765849056605), Count: 212
# Cluster 5: Center (-22.86074820754717, -43.37043764150943), Count: 212
# Cluster 27: Center (-22.85369861878453, -43.376198453038675), Count: 181
# Cluster 97: Center (-22.86197, -43.35585), Count: 175
# [639] Tamanho df filtrado: 25724
# Top selected areas:
# Cluster 1: Center (-22.81711754095309, -43.30159582743857), Count: 21488
# Cluster 48: Center (-22.8109410262418, -43.32980702436738), Count: 2134
# Cluster 30: Center (-22.92334146359584, -43.23476341010401), Count: 1346
# Cluster 98: Center (-22.809958185117967, -43.32912408348457), Count: 551
# Cluster 72: Center (-22.83880356097561, -43.33331375609756), Count: 205
# [665] Tamanho df filtrado: 36972
# Top selected areas:
# Cluster 2: Center (-22.792602480062694, -43.29440576038353), Count: 21693
# Cluster 7: Center (-22.858146171708913, -43.37118412428455), Count: 6115
# Cluster 0: Center (-22.817602700196183, -43.39338232744783), Count: 5607
# Cluster 12: Center (-22.806085433386837, -43.36354690609952), Count: 2492
# Cluster 22: Center (-22.922188553990612, -43.23265281690141), Count: 1065
# [756] Tamanho df filtrado: 26933
# Top selected areas:
# Cluster 0: Center (-22.875902665839046, -43.419415423436064), Count: 18527
# Cluster 47: Center (-22.832503346736047, -43.34250106196783), Count: 4228
# Cluster 13: Center (-22.915121755706046, -43.682697090544266), Count: 3987
# Cluster 19: Center (-22.91669361904762, -43.63255142857143), Count: 105
# Cluster 42: Center (-22.88035558139535, -43.35724046511628), Count: 86
# [759] Tamanho df filtrado: 3075
# Top selected areas:
# Cluster 0: Center (-22.935633354114714, -43.655969559434745), Count: 2406
# Cluster 11: Center (-22.831849465648855, -43.343181704834606), Count: 393
# Cluster 31: Center (-22.93708326923077, -43.65524769230769), Count: 104
# Cluster 63: Center (-22.879179444444443, -43.62051044444444), Count: 90
# Cluster 46: Center (-22.855260975609756, -43.49249975609756), Count: 82
# [774] Tamanho df filtrado: 15049
# Top selected areas:
# Cluster 1: Center (-22.81710884598958, -43.3015738276245), Count: 11707
# Cluster 0: Center (-22.80738343102216, -43.327467709077915), Count: 2798
# Cluster 60: Center (-22.870351138613863, -43.341908762376235), Count: 202
# Cluster 19: Center (-22.847771264367815, -43.32488005747126), Count: 174
# Cluster 40: Center (-22.877086547619047, -43.33405607142857), Count: 168
# [779] Tamanho df filtrado: 10062
# Top selected areas:
# Cluster 1: Center (-22.81732686090441, -43.393548682312534), Count: 8735
# Cluster 4: Center (-22.814827631257632, -43.38228118437119), Count: 819
# Cluster 0: Center (-22.806162630057802, -43.36759517341041), Count: 346
# Cluster 47: Center (-22.818212261904762, -43.39125333333333), Count: 84
# Cluster 24: Center (-22.80586794871795, -43.366923974358976), Count: 78
# [803] Tamanho df filtrado: 32053
# Top selected areas:
# Cluster 2: Center (-22.87589309262375, -43.41939841361906), Count: 22586
# Cluster 10: Center (-22.878883880330793, -43.49151936922328), Count: 6167
# Cluster 16: Center (-22.935894254658386, -43.371936836180126), Count: 2576
# Cluster 24: Center (-22.880186280834916, -43.35733836812144), Count: 527
# Cluster 3: Center (-22.88493954314721, -43.399778781725885), Count: 197
# [838] Tamanho df filtrado: 26597
# Top selected areas:
# Cluster 0: Center (-22.894023625227295, -43.53202157861996), Count: 20898
# Cluster 3: Center (-22.901589168656393, -43.55530828087693), Count: 4607
# Cluster 7: Center (-22.96827779904306, -43.62162958133971), Count: 836
# Cluster 9: Center (-22.928448092105263, -43.5733275), Count: 152
# Cluster 18: Center (-22.91271375, -43.56425211538462), Count: 104
# [852] Tamanho df filtrado: 6853
# Top selected areas:
# Cluster 0: Center (-22.89440757436319, -43.532342931799505), Count: 6085
# Cluster 17: Center (-22.901492895863054, -43.55479166904422), Count: 701
# Cluster 23: Center (-22.902474074074075, -43.55599629629629), Count: 27
# Cluster 43: Center (-22.962143333333334, -43.606028571428574), Count: 21
# Cluster 27: Center (-22.968201052631578, -43.62176947368421), Count: 19
# [864] Tamanho df filtrado: 49953
# Top selected areas:
# Cluster 0: Center (-22.894050188128446, -43.532046347418394), Count: 33913
# Cluster 2: Center (-22.901868112161722, -43.55577245516792), Count: 12268
# Cluster 1: Center (-22.87591469712016, -43.46365067858325), Count: 3021
# Cluster 4: Center (-22.875563742331288, -43.46542263803681), Count: 489
# Cluster 8: Center (-22.87948148854962, -43.50435549618321), Count: 262
# [867] Tamanho df filtrado: 16422
# Top selected areas:
# Cluster 10: Center (-22.89426015050778, -43.532148337108204), Count: 13687
# Cluster 0: Center (-22.901530812870448, -43.555024754445384), Count: 2362
# Cluster 74: Center (-22.90245625, -43.55597654411765), Count: 136
# Cluster 4: Center (-22.901277333333333, -43.55388518518519), Count: 135
# Cluster 2: Center (-23.066726568627452, -43.56793343137255), Count: 102
# [878] Tamanho df filtrado: 36420
# Top selected areas:
# Cluster 0: Center (-22.88012137404022, -43.35753910603291), Count: 27350
# Cluster 2: Center (-22.91561938365651, -43.36112754155125), Count: 7220
# Cluster 3: Center (-22.876196035502957, -43.419428806706115), Count: 1014
# Cluster 4: Center (-23.00813867595819, -43.30341911149826), Count: 574
# Cluster 23: Center (-22.97758786259542, -43.33406328244275), Count: 262
# [905] Tamanho df filtrado: 10184
# Top selected areas:
# Cluster 0: Center (-22.817117947284345, -43.30163073482428), Count: 7512
# Cluster 2: Center (-22.825273183111953, -43.33220390417457), Count: 2108
# Cluster 113: Center (-22.820051264822133, -43.31678561264822), Count: 253
# Cluster 3: Center (-22.86650550200803, -43.24963875502008), Count: 249
# Cluster 74: Center (-22.856473870967744, -43.24871516129032), Count: 62
# [917] Tamanho df filtrado: 1893
# Top selected areas:
# Cluster 2: Center (-22.876981209262436, -43.36783651801029), Count: 1166
# Cluster 0: Center (-22.878556018808776, -43.429404043887146), Count: 319
# Cluster 1: Center (-22.885678776595746, -43.399156223404255), Count: 188
# Cluster 5: Center (-22.878157777777776, -43.43032090277778), Count: 144
# Cluster 6: Center (-22.87798842105263, -43.36307644736842), Count: 76
# [918] Tamanho df filtrado: 24746
# Top selected areas:
# Cluster 2: Center (-22.894507073940282, -43.53241458182816), Count: 21869
# Cluster 21: Center (-22.89498170441676, -43.490636545866366), Count: 1766
# Cluster 25: Center (-22.867670457665906, -43.25689267734554), Count: 874
# Cluster 63: Center (-22.892608962962964, -43.529963333333335), Count: 135
# Cluster 6: Center (-22.88276068627451, -43.486312843137256), Count: 102

# %%
df_results_dict = {'linha':[], 'cluster_order':[], 'latitude':[], 'longitude':[], 'cluster_count':[]}
for linha, info_list in bus_stops_per_line.items():
    for info in info_list:
        df_results_dict['linha'].append(linha)
        df_results_dict['cluster_order'].append(info[0])
        df_results_dict['latitude'].append(info[1][0])
        df_results_dict['longitude'].append(info[1][1])
        df_results_dict['cluster_count'].append(info[2])
df_results = pd.DataFrame.from_dict(df_results_dict)
df_results = df_results.sort_values(by=['longitude', 'latitude'])
df_results.to_csv('calculated_bus_garage.csv', index=False)
display(df_results)
# Out:
#     linha  cluster_order   latitude  longitude  cluster_count
# 172   756              3 -22.915122 -43.682697           3987
# 175   759              1 -22.935633 -43.655970           2406
# 70    388              1 -22.935632 -43.655915           4759
# 177   759              3 -22.937083 -43.655248            104
# 173   756              4 -22.916694 -43.632551            105
# ..    ...            ...        ...        ...            ...
# 32    298              3 -22.909134 -43.170934            341
# 12    232              3 -22.908861 -43.170235            253
# 46    324              2 -22.825560 -43.169328           1016
# 51    328              2 -22.789024 -43.161897           2880
# 151   634              2 -22.789061 -43.161867           1439
#
# [235 rows x 5 columns]

# %%
def create_bus_stops_map(df: pd.DataFrame):
    map_center = [df['latitude'].mean(), df['longitude'].mean()]
    folium_map = folium.Map(location=map_center, zoom_start=12)
    
    colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']

    # mapeamento de cores
    linha_colors = {linha: colors[i % len(colors)] for i, linha in enumerate(df['linha'].unique())}

    # adicionar marcadores de circulo no mapa
    df = df.sort_values(by=['longitude', 'latitude'])
    i = 0
    for _, row in df.iterrows():
        popup_text = f"i:{i}<br>linha: {row['linha']}<br>cluster_order: {row['cluster_order']}<br>cluster_count: {row['cluster_count']}<br>Location:({row['latitude']}, {row['longitude']})"
        folium.Marker(
        location=(row['latitude'], row['longitude']),
        popup=folium.Popup(popup_text, max_width=300),
        icon=folium.Icon(color=linha_colors[row['linha']])
        ).add_to(folium_map)
        # adicionar circulo representando o raio
        folium.Circle(
            location=(row['latitude'], row['longitude']),
            radius=100,
            color=linha_colors[row['linha']],
            fill=True,
            fill_color=linha_colors[row['linha']],
            fill_opacity=0.2
        ).add_to(folium_map)
        i += 1

    # Salvar para arquivo html
    folium_map.save("maps/bus_garage_map.html")
create_bus_stops_map(df_results)

# %%
TABLE_COLUMNS = ['linha', 'cluster_order', 'latitude', 'longitude', 'cluster_count']
conn = conn = psycopg2.connect(host='localhost', database='postgres', user='postgres', password='skyping1')
def copy_data_from_csv(csv_file_path, conn):
    try:
        cursor = conn.cursor()
        with open(csv_file_path, 'r') as f:
            col_order = ', '.join(map(str, TABLE_COLUMNS))
            cursor.copy_expert(f"COPY garage ({col_order}) FROM STDIN DELIMITER ',' CSV HEADER", f)
        conn.commit()
        print(f"Data loaded from {csv_file_path} successfully")
    except Exception as e:
        print(f"Error: {e}")
        conn.rollback()

copy_data_from_csv('estimated_bus_garage.csv', conn)
